# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score

# %%
df = pd.read_csv('../data/cleaned.csv')
test = pd.read_csv('../data/test_cleaned.csv')

# %%
def predictions(line):
    print(line)
    #temp = pd.concat([group_list[model_list.index(line['model'])], line], ignore_index=True)
    temp = group_list[model_list.index(line['model'])]
    dummies = pd.get_dummies(temp, columns=['manufacturer', 'model', 'trim', 'color'], drop_first=True)
    print(temp)
    dummies.fillna(0)
    temp = dummies.tail(1)
    temp_X = temp.drop(columns=['name', 'price'])
    dummies.drop(index=dummies.index[-1], inplace=True)
    X = dummies.drop(columns=['name', 'price'])
    #print(X)
    y = dummies['price']
    lr = LinearRegression()
    lr.fit(X, y)
    pred = lr.predict(temp_X)
    return pred[0]

# %%
#print(test)
#test['predictions'] = test.apply(predictions, axis=1)

# %%
#test

# %%
# list comprehension below taken from https://stackoverflow.com/questions/23691133/split-pandas-dataframe-based-on-groupby

gb = df.groupby('model')    
group_list = [gb.get_group(x) for x in gb.groups]

# %%
# create model_list for indexing purposes

model_list = []
#model_dic = {}
for df in group_list:
    #dummies = pd.get_dummies(df, columns=['manufacturer', 'model', 'trim', 'color'], drop_first=True)
    #X = dummies.drop(columns=['name', 'price'])
    #y = df['price']
    #model_dic[str('_'.join(df.iat[0, 3].split()))] = LinearRegression()
    #model_dic[str('_'.join(df.iat[0, 3].split()))].fit(X, y)
    model_list.append('_'.join(df.iat[0, 3].split()))

# %%
#test_dummies = pd.get_dummies(test, columns=['manufacturer', 'model', 'trim', 'color'], drop_first=True)
#test_dummies.drop(columns=['name', 'price'], inplace=True)

# %%
#test_dummies = pd.get_dummies(test, columns=['manufacturer', 'model', 'trim', 'color'], drop_first=True)
#test_dummies.drop(columns=['name', 'price'], inplace=True)

# %%
# attempt to concat single row, remove, fit model, and get preds

def predictions(line):
    temp = pd.concat([group_list[model_list.index(line['model'])], line], ignore_index=True)
    dummies = pd.get_dummies(temp, columns=['manufacturer', 'model', 'trim', 'color'], drop_first=True)
    print(dummies)
    dummies.fillna(0)
    temp = dummies.tail(1)
    temp_X = temp.drop(columns=['name', 'price'])
    dummies.drop(index=dummies.index[-1], inplace=True)
    X = dummies.drop(columns=['name', 'price'])
    #print(X)
    y = dummies['price']
    lr = LinearRegression()
    lr.fit(X, y)
    pred = lr.predict(temp_X)
    return pred[0]

# %%
# attempt to concat single row, remove, fit model, and get preds
temp = pd.concat([group_list[model_list.index('RDX')], test], ignore_index=True)
#print(temp)
dummies = pd.get_dummies(temp, columns=['manufacturer', 'model', 'trim', 'color'], drop_first=True)
dummies.fillna(0)
temp = dummies.tail(1)
temp_X = temp.drop(columns=['name', 'price'])
dummies.drop(index=dummies.index[-1], inplace=True)
X = dummies.drop(columns=['name', 'price'])
y = dummies['price']
lr = LinearRegression()
lr.fit(X, y)
pred = lr.predict(temp_X)
pred[0]
# Out:
# 29085.055099063553

# %%
# attempt to concat single row, remove, fit model, and get preds
def row_prediction(row):
    try:
        mine = row.to_frame()
        #print(mine)
        #print('_'.join(mine.T.iat[0, 3].split()))
        #print(mine.T.columns)
        #print(group_list[model_list.index('RDX')].columns)
        #temp = pd.concat([group_list[model_list.index(row['model'])], mine.T], ignore_index=True)
        temp = pd.concat([group_list[model_list.index('_'.join(mine.T.iat[0, 3].split()))], mine.T], ignore_index=True)
        #'_'.join(row.iat[0, 3].split())
        #print(row)
        #print(temp)
        dummies = pd.get_dummies(temp, columns=['manufacturer', 'model', 'trim', 'color'], drop_first=True)
        dummies.fillna(0)
        temp = dummies.tail(1)
        temp_X = temp.drop(columns=['name', 'price'])
        dummies.drop(index=dummies.index[-1], inplace=True)
        X = dummies.drop(columns=['name', 'price'])
        y = dummies['price']
        lr = LinearRegression()
        lr.fit(X, y)
        pred = lr.predict(temp_X)
        return pred[0]
    except:
        return 'Model not in dataframe.'

# %%
df = pd.read_csv('../data/cleaned.csv')
# 6                       XT5            Premium Luxury    65319    Gray  32590
# 7                    Camaro                        LT    36861     Red  21990
# 8     Colorado Extended Cab           Work Truck 6 ft    53973    Blue  24590
# 9                     Cruze                       1LT    62484   White  15990
# 10                    Cruze                       1LT    86828   Brown  13990
# 11           Impala Limited                        LT    55716  Silver  15990
# 12  Silverado 1500 Crew Cab               LT 5 3/4 ft    70187   Black  35990
# 13                 Pacifica                   Limited     9324  Silver  43990
# 14                  Charger                   R/T Max    40428     Red  26590
# 15                  Charger        Scat Pack Widebody    28875    Blue  50990
# 16                  Journey                 Crossroad    70811    Gray  18590
# 17            Fusion Energi  Plug-In Hybrid SE Luxury    75874   Black  21990
# 18                  Mustang          EcoBoost Premium    43056   White  28990
# 19                   Accord                        LX    67218   White  15990
# 20                  Odyssey                        LX    98419   Other  17590
# 21                    Pilot                      EX-L    14796    Gray  40990
# 22                  Elantra                       GLS    81749  Silver  14590
# 23                 Santa Fe                        SE    98035     Red  20590
# 24    Sonata Plug-in Hybrid                   Limited    66627   Black  22990
# 25                 Cherokee                  Latitude    69817   White  20590
# 26                 Cherokee            Sport Altitude    56316    Gray  21990
# 27                Gladiator                Sport 5 ft     2787   Green  44990
# 28                  Patriot                      base    74007    Gray  14990
# 29                   Sedona                        SX    93682    Blue  20990
# 30                      LR2                       HSE    88099    Blue  17990
# 31                     CX-5                   Touring    90765   White  16990
# 32                      GLC            GLC 300 4MATIC    57418    Blue  35590
# 33     Mercedes-AMG C-Class                  C 43 AMG    41419   Black  41590
# 34                   Altima                    2.5 SL    86747    Blue  15990
# 35        Frontier King Cab                    S 6 ft    63937  Silver  19990
# 36               Pathfinder                        SV    57410   White  25590
# 37                   Sentra                         S    38559    Gray  13990
# 38                   Sentra                        SV    42204   White  19590
# 39                    Versa                        SV    43089   White  17590
# 40            1500 Quad Cab         Big Horn 6 1/3 ft    88866   Black  21590
# 41                  Impreza                      base    34972  Silver  22990
# 42                  Outback              2.5i Limited    38591   Green  29990
# 43                  Corolla                         S   102202  Silver  13990
# 44                  Corolla                         S    90688  Silver  16990
# 45                     RAV4                        LE    25620   White  29990
# 46                    Jetta                    2.0L S    64824  Silver  15990
# 47                   Passat                   1.8T SE    76244    Gray  16590
# 48                   Passat               2.0T R-Line    41257   White  22990
# 49                   Tiguan                   2.0T SE    34956    Blue  26590
# 50                     XC60            T5 Inscription    25230  Silver  31590
#
#                  prediction
# 0              29085.055099
# 1              24645.628191
# 2              22147.198171
# 3              35291.523386
# 4              26445.514796
# 5               25764.23731
# 6              34109.569331
# 7              21367.707194
# 8              24348.149888
# 9              16315.101295
# 10             15195.711716
# 11             17844.229581
# 12             33786.995769
# 13             41781.159607
# 14             37745.873824
# 15             55774.325028
# 16             19644.600344
# 17             22022.778591
# 18             31597.514449
# 19             14936.247313
# 20             18241.765012
# 21              41485.79301
# 22             14835.166146
# 23              22422.66503
# 24  Model not in dataframe.
# 25             21765.337852
# 26             21996.764596
# 27             43821.038383
# 28             15133.303349
# 29             20054.094607
# 30  Model not in dataframe.
# 31             16893.135525
# 32             33349.571673
# 33             40857.641523
# 34             17110.186534
# 35              20918.32019
# 36             29627.796213
# 37              9471.509542
# 38             21198.587925
# 39             18384.182623
# 40             19828.113237
# 41             23402.493441
# 42             28939.855155
# 43             13510.684663
# 44             17335.666189
# 45             31904.676374
# 46             16277.818829
# 47             16814.307161
# 48              22477.87864
# 49             24701.486527
# 50             27978.859473
